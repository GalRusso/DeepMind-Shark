# %% [markdown]
# # DLT pipeline
#
# This Delta Live Tables (DLT) definition is executed using a pipeline defined in resources/my_project.pipeline.yml.

# %%
# Import DLT and src/my_project
import dlt
import sys

sys.path.append(spark.conf.get("bundle.sourcePath", "."))
from pyspark.sql.functions import expr
from sample import utils

# %%
@dlt.view
def taxi_raw():
    return utils.get_taxis(spark)


@dlt.table
def filtered_taxis():
    return dlt.read("taxi_raw").filter(expr("fare_amount < 30"))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 @dlt.view
#       2 def taxi_raw():
#       3     return utils.get_taxis(spark)
#       6 @dlt.table
#       7 def filtered_taxis():
#
# File ~/Documents/GitHub/af-delivery-data-platform/.venv/lib/python3.12/site-packages/dlt/api.py:146, in view(query_function, name, comment, spark_conf)
#     123 def view(
#     124     query_function: Optional[Callable[..., DataFrame]] = None,
#     125     name: Optional[str] = None,
#     126     comment: Optional[str] = None,
#     127     spark_conf: Optional[Dict[str, str]] = None,
#     128 ) -> Union[Callable[[Callable[[], DataFrame]], Callable[[], DataFrame]]]:
#     129     """
#     130     (Return a) decorator to define a view in the pipeline and mark a function as the view's query
#     131     function.
# ...
